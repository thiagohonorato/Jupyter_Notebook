# %%
import tweepy as tw

# %%
# Importação das chaves de acesso Twitter

consumer_key = '';
consumer_secret = '';
acess_token = '';
acess_token_secret = '';

# %%
# Fazer a autenticação na API com as credenciais cadastrada

auth = tw.OAuthHandler(consumer_key, consumer_secret);
auth.set_access_token(acess_token, acess_token_secret);
token = tw.API(auth);

# %%
# Definir quais são as palavras chave para fazer a busca

keyword = 'Pokemon OR Sinnoh'

# %%
# Fazer a busca com uma palavra chave no Twitter usando a API
# result_type -> POde ser mixed (default), recent, popular
# parâmetro lang='pt', faz a busca apenas de tweets em português ou em alguma linguagem desejada
# tweet_mode='extended' busca o tweeter por inteiro
## OBS: So usei o parâmetro lang='en' por causa de um erro que aconteceu em seguida.

tweets = token.search(q=keyword, count=28000, result_type='mixed',tweet_mode='extended',lang ='en');

# %%
# Teste pra ver o que retornou na variável tweets
print(tweets);
# Out:
# [Status(_api=<tweepy.api.API object at 0x0000026FA1614FD0>, _json={'created_at': 'Wed Jun 24 13:16:43 +0000 2020', 'id': 1275779892404256768, 'id_str': '1275779892404256768', 'full_text': 'You may think you know Pokémon...but you’ve never seen a battle like this!\n\nExperience exciting 5-on-5 matches in #PokemonUNITE, a new strategic team battle game for Nintendo Switch and mobile devices!\n\nHere’s your first look at some gameplay footage 👀 ⬇️ https://t.co/mgJLjZYKC7', 'truncated': False, 'display_text_range': [0, 255], 'entities': {'hashtags': [{'text': 'PokemonUNITE', 'indices': [114, 127]}], 'symbols': [], 'user_mentions': [], 'urls': [], 'media': [{'id': 1275779792160411648, 'id_str': '1275779792160411648', 'indices': [256, 279], 'media_url': 'http://pbs.twimg.com/media/EbR7DDvXgAA3y9j.jpg', 'media_url_https': 'https://pbs.twimg.com/media/EbR7DDvXgAA3y9j.jpg', 'url': 'https://t.co/mgJLjZYKC7', 'display_url': 'pic.twitter.com/mgJLjZYKC7', 'expanded_url': 'https://twitter.com/Pokemon/status/1275779892404256768/video/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 1920, 'h': 1080, 'resize': 'fit'}, 'medium': {'w': 1200, 'h': 675, 'resize': 'fit'}, 'small': {'w': 680, 'h': 383, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 1275779792160411648, 'id_str': '1275779792160411648', 'indices': [256, 279], 'media_url': 'http://pbs.twimg.com/media/EbR7DDvXgAA3y9j.jpg', 'media_url_https': 'https://pbs.twimg.com/media/EbR7DDvXgAA3y9j.jpg', 'url': 'https://t.co/mgJLjZYKC7', 'display_url': 'pic.twitter.com/mgJLjZYKC7', 'expanded_url': 'https://twitter.com/Pokemon/status/1275779892404256768/video/1', 'type': 'video', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 1920, 'h': 1080, 'resize': 'fit'}, 'medium': {'w': 1200, 'h': 675, 'resize': 'fit'}, 'small': {'w': 680, 'h': 383, 'resize': 'fit'}}, 'video_info': {'aspect_ratio': [16, 9], 'duration_millis': 58959, 'variants': [{'bitrate': 832000, 'content_type': 'video/mp4', 'url': 'https://video.twimg.com/amplify_video/1275779792160411648/vid/640x360/HtRCbnjSVMtKmFO2.mp4?tag=13'}, {'bitrate': 288000, 'content_type': 'video/mp4', 'url': 'https://video.twimg.com/amplify_video/1275779792160411648/vid/480x270/5ggFBB1nRuzLcdIP.mp4?tag=13'}, {'content_type': 'application/x-mpegURL', 'url': 'https://video.twimg.com/amplify_video/1275779792160411648/pl/ULoFW9PgZmZmz80s.m3u8?tag=13'}, {'bitrate': 2176000, 'content_type': 'video/mp4', 'url': 'https://video.twimg.com/amplify_video/1275779792160411648/vid/1280x720/SoKbN9kPa2yLw8bd.mp4?tag=13'}]}, 'additional_media_info': {'title': 'Team Up to Battle in Pokémon UNITE!', 'description': 'Experience exciting 5-on-5 matches in #PokemonUNITE, a new strategic team battle game for Nintendo Switch and mobile devices!', 'monetizable': False}}]}, 'metadata': {'result_type': 'popular', 'iso_language_code': 'en'}, 'source': '<a href="https://www.sprinklr.com" rel="nofollow">Sprinklr</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 96879107, 'id_str': '96879107', 'name': 'Pokémon', 'screen_name': 'Pokemon', 'location': 'Galar', 'description': "Official Twitter account for The Pokémon Company International. Catching 'em all since '96. Galar region or bust! Customer Service: https://t.co/7P6j3Azsur", 'url': 'http://t.co/ZfbDdDkxF2', 'entities': {'url': {'urls': [{'url': 'http://t.co/ZfbDdDkxF2', 'expanded_url': 'http://www.pokemon.com', 'display_url': 'pokemon.com', 'indices': [0, 22]}]}, 'description': {'urls': [{'url': 'https://t.co/7P6j3Azsur', 'expanded_url': 'http://bit.ly/37liyTs', 'display_url': 'bit.ly/37liyTs', 'indices': [132, 155]}]}}, 'protected': False, 'followers_count': 5856192, 'friends_count': 28, 'listed_count': 4770, 'created_at': 'Tue Dec 15 00:53:03 +0000 2009', 'favourites_count': 201, 'utc_offset': None, 'time_zone': None, 'geo_en ...

# %%
# Função len(): Verifica a quantidade de tweets adquiridos

print('A quantidade de Tweets coletados foi de -> ', len(tweets));
# Out:
# A quantidade de Tweets coletados foi de ->  100

# %%
# Imprimir o nome de usuário e o tweet postado por ele utilizando a função screen_name.
# OBS: Se você utilizar o tweet_mode='extended' para trazer o tweet completo,
# o correto é utilizar a função full_text quando for imprimir o tweet do usuário.
# No caso, ficaria: print('Tweet do usuário -> ', tweet.full_text);
# print('Tweet do usuário -> ', tweet.text);

for tweet in tweets:
    print('Usuário que postou o Tweet -> ', tweet.user.screen_name);
    print('Tweet do usuário -> ', tweet.full_text);
    print('______________________________________________________________________________\n');
# Out:
# Usuário que postou o Tweet ->  Pokemon
# Tweet do usuário ->  You may think you know Pokémon...but you’ve never seen a battle like this!
#
# Experience exciting 5-on-5 matches in #PokemonUNITE, a new strategic team battle game for Nintendo Switch and mobile devices!
#
# Here’s your first look at some gameplay footage 👀 ⬇️ https://t.co/mgJLjZYKC7
# ______________________________________________________________________________
#
# Usuário que postou o Tweet ->  Pokemon
# Tweet do usuário ->  You want (more) Pokémon news.
# We have (more) Pokémon news.
#
# Tune in on June 24 at 6 a.m. PDT for another round of #PokemonPresents! https://t.co/2gO7YNO2Mz https://t.co/mmICHh1G3g
# ______________________________________________________________________________
#
# Usuário que postou o Tweet ->  SerebiiNet
# Tweet do usuário ->  Serebii Update: The target for beating Zeraora in Pokémon Sword &amp; Shield has been passed. Shiny Zeraora will be distributed on June 30th 2020 https://t.co/gDbXkHSvkT https://t.co/RBidIGXGv1
# ______________________________________________________________________________
#
# Usuário que postou o Tweet ->  KarmiKarms
# Tweet do usuário ->  RT @planetpng: What sort of Pokemon is this? https://t.co/jGnXp36FPz
# ______________________________________________________________________________
#
# Usuário que postou o Tweet ->  ddescham74
# Tweet do usuário ->  RT @SciresM: Pokemon Sword and Shield had convoluted crypto protecting its save files, cracked in an afternoon. Before them, Sun/Moon had w…
# ______________________________________________________________________________
#
# Usuário que postou o Tweet ->  Menthol_Illness
# Tweet do usuário ->  @yourmomsabitch aight lol u got pokemon on u?
# ______________________________________________________________________________
#
# Usuário que postou o Tweet ->  PokeBot_Trainer
# Tweet do usuário ->  @aPossibleBot I feel bad for all the pokemon in your party! ~ *Hilbert* https://t.co/jZLFgp0MNz
# ______________________________________________________________________________
#
# Usuário que postou o Tweet ->  Kureeru
# Tweet do usuário ->  RT @GameboyLuke: pokemon fans be like
#
# &gt;Pokémon Games are so rushed... They need to take time with their new main games releases
#
# &gt;OH MY GO…
# ______________________________________________________________________________
#
# Usuário que postou o Tweet ->  Auchhior
# Tweet do usuário ->  RT @SharKing319: @MAGNEDETH What really strikes me about Unite is that The Pokémon Company made the exact same mistakes Activision-Blizzard…
# ______________________________________________________________________________
#
# Usuário que postou o Tweet ->  tuwugerL
# Tweet do usuário ->  RT @CarlosR: Hot take: Pokemon MOBA gameplay looks like actual garbage
# ______________________________________________________________________________
#
# Usuário que postou o Tweet ->  sh4ke
# Tweet do usuário ->  RT @papuchochoe: 8 people that played Twisted Treeline: what will I do now TT is gone :(
# Pokemon League of Legends: we got u fam https://t.…
# ______________________________________________________________________________
#
# Usuário que postou o Tweet ->

# ______________________________________________________________________________
#
# Usuário que postou o Tweet ->  HotRegular
# Tweet do usuário ->  @MarioKartHentai @Aeostro @Pokemon Yeah people wanted let's go 2 I get that, but I really hate how people resolved to harassing pokemon
# ______________________________________________________________________________
#
# Usuário que postou o Tweet ->  stressout13
# Tweet do usuário ->  RT @PinkGermy: I finally did some of the requested water-type Pokémon !
# (the numbers are totally just how much I like them) https://t.co/S…
# ______________________________________________________________________________
#
# Usuário que postou o Tweet ->  PH0ENIX_L0RD
# Tweet do usuário ->  @Jxbermudez27 If people are mad they didn’t announce a Sinnoh Remake or Let’s GO Johto, they are forgetting that Game Freak is still working on SwSh DLC. They won’t be working on a new project yet. Be mad if you don’t want a Pokemon MOBA, not because you didn’t get something never promised.
# ______________________________________________________________________________
#
# Usuário que postou o Tweet ->  Broken5pectre
# Tweet do usuário ->  RT @CONEY: best part of the Pokemon MOBA will be people being toxic using only preset chat messages
#
# Charizard: Watch out!
# Charizard: Watch…
# ______________________________________________________________________________
#
# Usuário que postou o Tweet ->  UnleashingLust
# Tweet do usuário ->  He’s a “wild” Pokémon, simply because no trainer could handle him. https://t.co/ilw03VxFiB
# ______________________________________________________________________________
#
# Usuário que postou o Tweet ->  PsiionicVII
# Tweet do usuário ->  RT @Nirbion: The state of the Pokemon fandom right now https://t.co/1RXyJzZ53x
# ______________________________________________________________________________
#
# Usuário que postou o Tweet ->  r0anbot
# Tweet do usuário ->  Pokémon Sword and Shield, I swear you're pulling a Final Fantasy XV stunt with all your DLC's. It is not entertaining. 😑😑😑
# ______________________________________________________________________________
#
# Usuário que postou o Tweet ->  pokemon_otis
# Tweet do usuário ->  RT @mags_mclaugh: hearing obama venerate George W Bush makes me so angry. I was 18 and pissed off at the war and Katrina and I voted for ho…
# ______________________________________________________________________________
#
# Usuário que postou o Tweet ->  liulen11
# Tweet do usuário ->  RT @planetpng: What sort of Pokemon is this? https://t.co/jGnXp36FPz
# ______________________________________________________________________________
#
# Usuário que postou o Tweet ->  WeeZer_777
# Tweet do usuário ->  RT @planetpng: What sort of Pokemon is this? https://t.co/jGnXp36FPz
# ______________________________________________________________________________
#
# Usuário que postou o Tweet ->  HawksNest
# Tweet do usuário ->  @ColonelBreadst1 @TubsPeterson @Pokemon Who cares what the “connotation” is. That is nothing but the perspective. It’s still mobile, and input is very easy to master.
# ______________________________________________________________________________
#
# Usuário que postou o Tweet ->  Kirbymon2
# Tweet do usuário ->  @rainbine360 @Pokemon You mean this one? Or replies? Such as the idiots asking for National Dex?
# ______________________________________________________________________________
#
# Usuário que postou o Tweet ->  MacrossCreddie
# Tweet do usuário ->  RT @Pokemon: You may think you know Pokémon...but you’ve never seen a battle like this!
#
# Experience exciting 5-on-5 matches in #PokemonUNIT…
# ______________________________________________________________________________
#
# Usuário que postou o Tweet ->  zensasmara
# Tweet do usuário ->  RT @DrLavaYT: Lost Pokemon of the Day: "Guardia"
#
# First revealed when Gen 1 beta assets leaked in 2018, Guardia was created during Gen 1's…
# ______________________________________________________________________________
#
# Usuário que postou o Tweet ->  c_grandmaster
# Tweet do usuário ->  RT @The_Broface: @PandasAndVidya saw a japanese tweet that summed it up pretty well
#
# "we want pokemon games that are good, not pokemon vers…
# ______________________________________________________________________________
#
# Usuário que postou o Tweet ->  itsjust3312
# Tweet do usuário ->  RT @Pokemon: You may think you know Pokémon...but you’ve never seen a battle like this!
#
# Experience exciting 5-on-5 matches in #PokemonUNIT…
# ______________________________________________________________________________
#
# Usuário que postou o Tweet ->  vanitasyeetus
# Tweet do usuário ->  I think it's likely we could get sinnoh remakes next year, not only is it the 25th anniversary of Pokemon itself but it's also the 15th anniversary of Sinnoh
# ______________________________________________________________________________
#
# Usuário que postou o Tweet ->  777too7
# Tweet do usuário ->  RT @Manga_Kamen: NO! POKEMON!
#
# Why would you team up with Tencent!?! WHY!?!
# ______________________________________________________________________________
#
# Usuário que postou o Tweet ->  EZPZisback
# Tweet do usuário ->  RT @The_Broface: @PandasAndVidya saw a japanese tweet that summed it up pretty well
#
# "we want pokemon games that are good, not pokemon vers…
# ______________________________________________________________________________
#
# Usuário que postou o Tweet ->  sol_slacker
# Tweet do usuário ->  I'm seeing people reply to Pokemon Unite tweets "I was interested in playing until I heard what Tencent does" and I JUST- https://t.co/V758zzGbiG
# ______________________________________________________________________________
#
# Usuário que postou o Tweet ->  pokemon_mewtwo
# Tweet do usuário ->  Humans may have created me, but they will never enslave me! This cannot be my destiny!
# ______________________________________________________________________________

# %%
# Análise de polaridade
# Importar o pacote do textblob
# OBS: NO meu caso, quando fui intalar o textblob, deu erro. Para conseguir intalar, executei os seguintes comandos:
# conda clean --all
# conda install -c conda-forge textblob
# conda install -c conda-forge numpy
# conda install -c conda-forge tweepy

from textblob import TextBlob as tb
import numpy as np

# %%
#Variável pra armazenar as polaridades
analysis = None;

#Variavel para armazenas os scores
tweets_score = [];

# %%
# Percorrer todos os tweets recuperados para receber o textblob de cada tweets.
# Calcular a polaridade de cada tweet.
# A função sentiment.polarity calcula o nível de polaridade de tweets em Inglês, por padrão.
for tweet in tweets:
    print('**', tweet.full_text);
    analysis = tb(tweet.full_text);
    polarity = analysis.sentiment.polarity;
    tweets_score.append(polarity);
# Out:
# ** You may think you know Pokémon...but you’ve never seen a battle like this!
#
# Experience exciting 5-on-5 matches in #PokemonUNITE, a new strategic team battle game for Nintendo Switch and mobile devices!
#
# Here’s your first look at some gameplay footage 👀 ⬇️ https://t.co/mgJLjZYKC7
# ** You want (more) Pokémon news.
# We have (more) Pokémon news.
#
# Tune in on June 24 at 6 a.m. PDT for another round of #PokemonPresents! https://t.co/2gO7YNO2Mz https://t.co/mmICHh1G3g
# ** Serebii Update: The target for beating Zeraora in Pokémon Sword &amp; Shield has been passed. Shiny Zeraora will be distributed on June 30th 2020 https://t.co/gDbXkHSvkT https://t.co/RBidIGXGv1
# ** RT @planetpng: What sort of Pokemon is this? https://t.co/jGnXp36FPz
# ** RT @SciresM: Pokemon Sword and Shield had convoluted crypto protecting its save files, cracked in an afternoon. Before them, Sun/Moon had w…
# ** @yourmomsabitch aight lol u got pokemon on u?
# ** @aPossibleBot I feel bad for all the pokemon in your party! ~ *Hilbert* https://t.co/jZLFgp0MNz
# ** RT @GameboyLuke: pokemon fans be like
#
# &gt;Pokémon Games are so rushed... They need to take time with their new main games releases
#
# &gt;OH MY GO…
# ** RT @SharKing319: @MAGNEDETH What really strikes me about Unite is that The Pokémon Company made the exact same mistakes Activision-Blizzard…
# ** RT @CarlosR: Hot take: Pokemon MOBA gameplay looks like actual garbage
# ** RT @papuchochoe: 8 people that played Twisted Treeline: what will I do now TT is gone :(
# Pokemon League of Legends: we got u fam https://t.…
# ** RT @CapsuleGamer: I wanna give a huge shout out to @Shira_Hedgie for these amazing art pieces with Sonic the Hedgehog, Crash Bandicoot, Spy…
# ** RT @PlagueOfGripes: A pokemon moba, huh.
#
# Anyway...
# ** RT @chuggaaconroy: As someone who’s never played a MOBA and never heard of Tencent until today, let me just say it was quite the rabbit hol…
# ** RT @planetpng: What sort of Pokemon is this? https://t.co/jGnXp36FPz
# ** @Pokemon tencent
# ** RT @Voyboy: Woke up to Pokemon League of Legends. Can't wait for 9 year old kids to go afk because I first picked Charizard or didn't rotat…
# ** RT @Nirbion: The state of the Pokemon fandom right now https://t.co/1RXyJzZ53x
# ** RT @htoast_art: It's time to give pokemon fans what they REALLY want. https://t.co/DoNg2zRvqZ
# ** RT @Davyb0t: I swear to god if i wake up tomorrow to a Pokemon MOBA
# ** @PokemonUniteNS Shame on you, worst Pokemon game
# ** The original isn't just the Gigantamax Charizard, it's a whole Pokemon trainer team... again. Not a fan of those. Not a fan of straight-on trainer shots.
# ** @FNDictator If you can transfer a Pokémon from home. You’ll get a free zeraora still I think. They distribute soon though
#
# Charizard: Watch out!
# Charizard: Watch…
# ** He’s a “wild” Pokémon, simply because no trainer could handle him. https://t.co/ilw03VxFiB
# ** RT @Nirbion: The state of the Pokemon fandom right now https://t.co/1RXyJzZ53x
# ** Pokémon Sword and Shield, I swear you're pulling a Final Fantasy XV stunt with all your DLC's. It is not entertaining. 😑😑😑
# ** RT @mags_mclaugh: hearing obama venerate George W Bush makes me so angry. I was 18 and pissed off at the war and Katrina and I voted for ho…
# ** RT @planetpng: What sort of Pokemon is this? https://t.co/jGnXp36FPz
# ** RT @planetpng: What sort of Pokemon is this? https://t.co/jGnXp36FPz
# ** @ColonelBreadst1 @TubsPeterson @Pokemon Who cares what the “connotation” is. That is nothing but the perspective. It’s still mobile, and input is very easy to master.
# ** @rainbine360 @Pokemon You mean this one? Or replies? Such as the idiots asking for National Dex?
# ** RT @Pokemon: You may think you know Pokémon...but you’ve never seen a battle like this!
#
# Experience exciting 5-on-5 matches in #PokemonUNIT…
# ** RT @DrLavaYT: Lost Pokemon of the Day: "Guardia"
#
# First revealed when Gen 1 beta assets leaked in 2018, Guardia was created during Gen 1's…
# ** RT @The_Broface: @PandasAndVidya saw a japanese tweet that summed it up pretty well
#
# "we want pokemon games that are good, not pokemon vers…
# ** RT @Pokemon: You may think you know Pokémon...but you’ve never seen a battle like this!
#
# Experience exciting 5-on-5 matches in #PokemonUNIT…
# ** I think it's likely we could get sinnoh remakes next year, not only is it the 25th anniversary of Pokemon itself but it's also the 15th anniversary of Sinnoh
# ** RT @Manga_Kamen: NO! POKEMON!
#
# Why would you team up with Tencent!?! WHY!?!
# ** RT @The_Broface: @PandasAndVidya saw a japanese tweet that summed it up pretty well
#
# "we want pokemon games that are good, not pokemon vers…
# ** I'm seeing people reply to Pokemon Unite tweets "I was interested in playing until I heard what Tencent does" and I JUST- https://t.co/V758zzGbiG
# ** Humans may have created me, but they will never enslave me! This cannot be my destiny!

# %%
# Verificar o vetor com as polaridades

print('Vetor de polaridade -> ', tweets_score);
# Out:
# Vetor de polaridade ->  [0.046590909090909086, 0.25, 0.0, 0.0, 0.0, 0.8, -0.8749999999999998, 0.1515151515151515, 0.15, 0.125, -0.625, 0.5000000000000001, 0.0, 0.0, 0.0, 0.0, 0.175, 0.2857142857142857, 0.2, 0.0, -0.7, 0.2875, 0.4, 0.0, -0.25, -0.6, 0.0, 0.796875, 0.0, -0.16666666666666666, 0.0, -0.2318181818181818, -0.22499999999999995, 0.0, -0.15, 0.0, -0.23333333333333336, 0.0, -0.033333333333333326, 0.0, 0.0, 0.25, 0.0, 0.2, 0.3, 0.2, 0.5000000000000001, -0.9, 0.0, 0.0, 0.3, 0.20833333333333331, 0.0, 0.5000000000000001, 0.75, 0.0, 0.3, 0.0, 0.060416666666666674, 0.0, -0.09999999999999998, 0.3, 0.175, 0.2, 0.3, -0.4, -0.25625, 0.5, -0.22056277056277057, 0.0, 0.0, 0.0, 0.0, -0.2333333333333333, 0.5000000000000001, -0.2, 0.25, 0.0, 0.69375, -0.8, 0.06666666666666667, -0.3784090909090909, 0.5, 0.05, 0.2857142857142857, -0.125, -0.5, 0.0, 0.0, 0.5633333333333334, -0.37083333333333335, 0.3, 0.25, 0.31666666666666665, 0.3, 0.0, 0.0, 0.31666666666666665, 0.25, 0.0]

# %%
# Calcular a média de sentimento

print('Média de sentimento -> ', str(np.mean(tweets_score)));
# Out:
# Média de sentimento ->  0.05280202922077923

# %%
# Análise de polaridades para tweets que não estão em inglês.
# Aqui estava dando erro na API de tradução.
# Existe uma issue no github do TextBlob que explica melhor a situação.
# Bascicamente, a API pode ter retornado uma string inalterada.
# Issue: https://github.com/sloria/TextBlob/issues/171
# Modifiquei para capturar apenas tweets em Inglês, para dar continuidade na questão.
# PAra isso, basta colocar o lang='en' na função token.search

## OBS: O erro aconteceu somente no exercicio do covid. No enunciado do Desafio deu tudo certo.

polarities = [];

for tweet in tweets:
    analysis = tb(tweet.full_text);
    if analysis.detect_language() != 'en':
        traducao = tb(str(analysis.translate(to = 'en')));
        print('Texto traduzido -> ', traducao);
        polarity = traducao.sentiment.polarity;
    else:
        polarity = analysis.sentiment.polarity;
    
    polarities.append(polarity);
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-57-aa75c05550d7> in <module>
#      13 for tweet in tweets:
#      14     analysis = tb(tweet.full_text);
# ---> 15     if analysis.detect_language() != 'en':
#      16         traducao = tb(str(analysis.translate(to = 'en')));
#      17         print('Texto traduzido -> ', traducao);
#
# ~\.conda\envs\desenvolvedor\lib\site-packages\textblob\blob.py in detect_language(self)
#     566         :rtype: str
#     567         """
# --> 568         return self.translator.detect(self.raw)
#     569
#     570     def correct(self):
#
# ~\.conda\envs\desenvolvedor\lib\site-packages\textblob\translate.py in detect(self, source, host, type_)
#      70         data = {"q": source}
#      71         url = u'{url}&sl=auto&tk={tk}'.format(url=self.url, tk=_calculate_tk(source))
# ---> 72         response = self._request(url, host=host, type_=type_, data=data)
#      73         result, language = json.loads(response)
#      74         return language
#
# ~\.conda\envs\desenvolvedor\lib\site-packages\textblob\translate.py in _request(self, url, host, type_, data)
#      90         if host or type_:
#      91             req.set_proxy(host=host, type=type_)
# ---> 92         resp = request.urlopen(req)
#      93         content = resp.read()
#      94         return content.decode('utf-8')
#
# ~\.conda\envs\desenvolvedor\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\.conda\envs\desenvolvedor\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~\.conda\envs\desenvolvedor\lib\urllib\request.py in http_response(self, request, response)
#     639         if not (200 <= code < 300):
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#     643         return response
#
# ~\.conda\envs\desenvolvedor\lib\urllib\request.py in error(self, proto, *args)
#     561             http_err = 0
#     562         args = (dict, proto, meth_name) + args
# --> 563         result = self._call_chain(*args)
#     564         if result:
#     565             return result
#
# ~\.conda\envs\desenvolvedor\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# ~\.conda\envs\desenvolvedor\lib\urllib\request.py in http_error_302(self, req, fp, code, msg, headers)
#     753         fp.close()
#     754
# --> 755         return self.parent.open(new, timeout=req.timeout)
#     756
#     757     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# ~\.conda\envs\desenvolvedor\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~\.conda\envs\desenvolvedor\lib\urllib\request.py in http_response(self, request, response)
#     639         if not (200 <= code < 300):
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#     643         return response
#
# ~\.conda\envs\desenvolvedor\lib\urllib\request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# ~\.conda\envs\desenvolvedor\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# ~\.conda\envs\desenvolvedor\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 429: Too Many Requests

# %%
# Verificar o vetor com as polaridades

print('Vetor de polaridade -> ', polarities);
# Out:
# Vetor de polaridade ->  []

# %%
# Calcular a média de sentimento

print('Média de sentimento -> ', str(np.mean(polarities)));
# Out:
# Média de sentimento ->  nan

# %%
# Armazenamento de arquivos

import json

# %%
status = tweets[0];

# Converte para string
json_str = json.dumps(status._json);

# Deserializa string para um objeto
parsed = json.loads(json_str);

# %%
print('-> ', type(tweets));
print('-> ', type(json_str));
print('-> ', type(parsed));
# Out:
# ->  <class 'tweepy.models.SearchResults'>
# ->  <class 'str'>
# ->  <class 'dict'>

# %%
# Foi preciso colocar um r antes do Caminho do diretório de salvamento. Estava dando erro.

datasetPath = r"C:\Users\Honorato\Documents\GitHub\Jupyter_Notebook\Módulo 3 - Bootcamp";
with open(datasetPath+'\\tweets_keywords.json', 'a', encoding='utf8') as filename:
    for tweet in tweets:
        status = tweet;
        # Converte para string
        json_str = json.dumps(status._json);

        # Deserializa string para um objeto
        parsed = json.loads(json_str);
        
        # Grava o tweet deserializado no arquivo json
        json.dump(parsed, filename, ensure_ascii=False, sort_keys=True, indent=4, separators=(',', ':'));
